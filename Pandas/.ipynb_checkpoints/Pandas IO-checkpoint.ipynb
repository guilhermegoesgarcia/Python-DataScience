# %% [markdown]
# # Criando os nomes

# %%
import pandas as pd

# %%
nomes_f = pd.read_json("https://servicodados.ibge.gov.br/api/v1/censos/nomes/ranking?qtd=200&sexo=f")
nomes_m = pd.read_json("https://servicodados.ibge.gov.br/api/v1/censos/nomes/ranking?qtd=200&sexo=m")

# %%
print(f'Quantidade de nomes: {len(nomes_f)+len(nomes_m)}')
# Out:
# Quantidade de nomes: 400

# %%
frames = [nomes_f,nomes_m]

# %%
nomes = pd.concat(frames)['nome'].to_frame()

# %%
nomes.sample(5)
# Out:
#         nome
# 147  ALISSON
# 109  GEOVANA
# 5    JULIANA
# 64   VIVIANE
# 187    ELTON

# %% [markdown]
# ## Incluindo ID dos alunos:

# %%
    import numpy as np

# %%
total_alunos = len(nomes)
total_alunos
# Out:
# 400

# %%
nomes['id_alunos'] = np.random.permutation(total_alunos)+1
nomes.head(10)
# Out:
#         nome  id_alunos
# 0      MARIA        126
# 1        ANA         66
# 2  FRANCISCA        295
# 3    ANTONIA        272
# 4    ADRIANA        235
# 5    JULIANA        193
# 6     MARCIA        271
# 7   FERNANDA        375
# 8   PATRICIA        228
# 9      ALINE         62

# %%
dominios = ['@dominiodoemail.com.br', '@servicodoemail.com']
nomes['dominio'] = np.random.choice(dominios,total_alunos)
nomes['e-mail'] = nomes.nome.str.cat(nomes.dominio).str.lower()

# %%
nomes.sample(5)
# Out:
#         nome  id_alunos                 dominio                         e-mail
# 197  MICHAEL        148  @dominiodoemail.com.br  michael@dominiodoemail.com.br
# 183   MARLON         81  @dominiodoemail.com.br   marlon@dominiodoemail.com.br
# 96     TANIA        224  @dominiodoemail.com.br    tania@dominiodoemail.com.br
# 22     ANDRE        327  @dominiodoemail.com.br    andre@dominiodoemail.com.br
# 81      LUAN        374  @dominiodoemail.com.br     luan@dominiodoemail.com.br

# %% [markdown]
# ## Criando a tabela cursos:

# %%
# !pip3 install html5lib
# !pip3 install lxml
# Out:
# Requirement already satisfied: html5lib in c:\users\guilherme\anaconda3\lib\site-packages (1.0.1)
# Requirement already satisfied: six>=1.9 in c:\users\guilherme\anaconda3\lib\site-packages (from html5lib) (1.12.0)
# Requirement already satisfied: webencodings in c:\users\guilherme\anaconda3\lib\site-packages (from html5lib) (0.5.1)
# Requirement already satisfied: lxml in c:\users\guilherme\anaconda3\lib\site-packages (4.3.2)

# %%
# !pip install --upgrade pip --user
# Out:
# Requirement already up-to-date: pip in c:\users\guilherme\anaconda3\lib\site-packages (20.2.2)

# %%
import html5lib

# %%
url = 'http://tabela-cursos.herokuapp.com/index.html'
cursos = pd.read_html(url)
cursos
# Out:
# [                          Nome do curso
#  0                 Lógica de programação
#  1                         Java para Web
#  2                           C# para Web
#  3                         Ruby on Rails
#  4                      Cursos de Python
#  5                         PHP com MySql
#  6                         .NET para web
#  7            Novas integrações com Java
#  8                          TDD com Java
#  9                   Código limpo com C#
#  10  Preparatório para certificação Java
#  11                      Hardware básico
#  12                Persistência com .NET
#  13                  Desenvolvendo jogos
#  14                     Análise de dados
#  15                   Estatística básica
#  16                  Internet das coisas
#  17                Programação funcional
#  18                Boas práticas em Java
#  19          Orientação objetos com Java]

# %%
cursos = cursos[0]

# %%
cursos
# Out:
#                           Nome do curso
# 0                 Lógica de programação
# 1                         Java para Web
# 2                           C# para Web
# 3                         Ruby on Rails
# 4                      Cursos de Python
# 5                         PHP com MySql
# 6                         .NET para web
# 7            Novas integrações com Java
# 8                          TDD com Java
# 9                   Código limpo com C#
# 10  Preparatório para certificação Java
# 11                      Hardware básico
# 12                Persistência com .NET
# 13                  Desenvolvendo jogos
# 14                     Análise de dados
# 15                   Estatística básica
# 16                  Internet das coisas
# 17                Programação funcional
# 18                Boas práticas em Java
# 19          Orientação objetos com Java

# %% [markdown]
# ## Alterando Index de curso

# %%
cursos = cursos.rename(columns = {'Nome do curso':'nome_do_curso'})

# %%
cursos.head(5)
# Out:
#            nome_do_curso
# 0  Lógica de programação
# 1          Java para Web
# 2            C# para Web
# 3          Ruby on Rails
# 4       Cursos de Python

# %%
cursos['id'] = cursos.index +1

# %%
cursos.head()
# Out:
#            nome_do_curso  id
# 0  Lógica de programação   1
# 1          Java para Web   2
# 2            C# para Web   3
# 3          Ruby on Rails   4
# 4       Cursos de Python   5

# %%
cursos = cursos.set_index('id')

# %%
cursos.head()
# Out:
#             nome_do_curso
# id
# 1   Lógica de programação
# 2           Java para Web
# 3             C# para Web
# 4           Ruby on Rails
# 5        Cursos de Python

# %% [markdown]
# ## Matriculando os alunos nos cursos:

# %%
nomes.head()
# Out:
#         nome  id_alunos                 dominio  \
# 0      MARIA        126  @dominiodoemail.com.br
# 1        ANA         66     @servicodoemail.com
# 2  FRANCISCA        295  @dominiodoemail.com.br
# 3    ANTONIA        272  @dominiodoemail.com.br
# 4    ADRIANA        235     @servicodoemail.com
#
#                             e-mail
# 0      maria@dominiodoemail.com.br
# 1           ana@servicodoemail.com
# 2  francisca@dominiodoemail.com.br
# 3    antonia@dominiodoemail.com.br
# 4       adriana@servicodoemail.com

# %%
nomes['matriculas'] = np.ceil(np.random.exponential(size = total_alunos)*1.5).astype(int)
nomes
# Out:
#           nome  id_alunos                 dominio  \
# 0        MARIA        126  @dominiodoemail.com.br
# 1          ANA         66     @servicodoemail.com
# 2    FRANCISCA        295  @dominiodoemail.com.br
# 3      ANTONIA        272  @dominiodoemail.com.br
# 4      ADRIANA        235     @servicodoemail.com
# 5      JULIANA        193     @servicodoemail.com
# 6       MARCIA        271     @servicodoemail.com
# 7     FERNANDA        375     @servicodoemail.com
# 8     PATRICIA        228     @servicodoemail.com
# 9        ALINE         62     @servicodoemail.com
# 10      SANDRA        173     @servicodoemail.com
# 11      CAMILA        259  @dominiodoemail.com.br
# 12      AMANDA        163  @dominiodoemail.com.br
# 13       BRUNA        187  @dominiodoemail.com.br
# 14     JESSICA        217     @servicodoemail.com
# 15     LETICIA         58     @servicodoemail.com
# 16       JULIA        258  @dominiodoemail.com.br
# 17     LUCIANA        202     @servicodoemail.com
# 18     VANESSA        181  @dominiodoemail.com.br
# 19     MARIANA         23  @dominiodoemail.com.br
# 20    GABRIELA        310     @servicodoemail.com
# 21        VERA        156     @servicodoemail.com
# 22     VITORIA        122  @dominiodoemail.com.br
# 23     LARISSA        276     @servicodoemail.com
# 24     CLAUDIA        367     @servicodoemail.com
# 25     BEATRIZ        233     @servicodoemail.com
# 26        RITA        206     @servicodoemail.com
# 27       LUANA        236     @servicodoemail.com
# 28       SONIA        326  @dominiodoemail.com.br
# 29      RENATA        332  @dominiodoemail.com.br
# ..         ...        ...                     ...
# 170  ALEXANDRO         94  @dominiodoemail.com.br
# 171   VALDEMIR        169     @servicodoemail.com
# 172  WANDERSON        102     @servicodoemail.com
# 173    JAILSON         78     @servicodoemail.com
# 174      DENIS        178     @servicodoemail.com
# 175       RIAN        108  @dominiodoemail.com.br
# 176      CELIO        232  @dominiodoemail.com.br
# 177  CLAUDINEI        195  @dominiodoemail.com.br
# 178   DENILSON        297     @servicodoemail.com
# 179       IAGO         93  @dominiodoemail.com.br
# 180       EDER        316  @dominiodoemail.com.br
# 181       YURI        227     @servicodoemail.com
# 182    CHARLES         87  @dominiodoemail.com.br
# 183     MARLON         81  @dominiodoemail.com.br
# 184     ALISON        382     @servicodoemail.com
# 185    JONATAN        351  @dominiodoemail.com.br
# 186       ERIC        116     @servicodoemail.com
# 187      ELTON         91     @servicodoemail.com
# 188   VALDECIR        379  @dominiodoemail.com.br
# 189     WESLEI        176     @servicodoemail.com
# 190   NATANAEL        397     @servicodoemail.com
# 191      ERICK        135     @servicodoemail.com
# 192    AGNALDO        372     @servicodoemail.com
# 193      KAUAN        331     @servicodoemail.com
# 194      ODAIR        369     @servicodoemail.com
# 195     WALTER         63     @servicodoemail.com
# 196    ARLINDO         51  @dominiodoemail.com.br
# 197    MICHAEL        148  @dominiodoemail.com.br
# 198     ALVARO         45     @servicodoemail.com
# 199    GEOVANE         64     @servicodoemail.com
#
#                               e-mail  matriculas
# 0        maria@dominiodoemail.com.br           1
# 1             ana@servicodoemail.com           5
# 2    francisca@dominiodoemail.com.br           1
# 3      antonia@dominiodoemail.com.br           3
# 4         adriana@servicodoemail.com           1
# 5         juliana@servicodoemail.com           2
# 6          marcia@servicodoemail.com           3
# 7        fernanda@servicodoemail.com           4
# 8        patricia@servicodoemail.com           1
# 9           aline@servicodoemail.com           2
# 10         sandra@servicodoemail.com           2
# 11      camila@dominiodoemail.com.br           1
# 12      amanda@dominiodoemail.com.br           3
# 13       bruna@dominiodoemail.com.br           1
# 14        jessica@servicodoemail.com           2
# 15        leticia@servicodoemail.com           1
# 16       julia@dominiodoemail.com.br           1
# 17        luciana@servicodoemail.com           2
# 18     vanessa@dominiodoemail.com.br           3
# 19     mariana@dominiodoemail.com.br           8
# 20       gabriela@servicodoemail.com           3
# 21           vera@servicodoemail.com           1
# 22     vitoria@dominiodoemail.com.br           4
# 23        larissa@servicodoemail.com           6
# 24        claudia@servicodoemail.com           4
# 25        beatriz@servicodoemail.com           1
# 26           rita@servicodoemail.com           1
# 27          luana@servicodoemail.com           1
# 28       sonia@dominiodoemail.com.br           4
# 29      renata@dominiodoemail.com.br           3
# ..                               ...         ...
# 170  alexandro@dominiodoemail.com.br           1
# 171      valdemir@servicodoemail.com           1
# 172     wanderson@servicodoemail.com           1
# 173       jailson@servicodoemail.com           1
# 174         denis@servicodoemail.com           1
# 175       rian@dominiodoemail.com.br           6
# 176      celio@dominiodoemail.com.br           5
# 177  claudinei@dominiodoemail.com.br           1
# 178      denilson@servicodoemail.com           2
# 179       iago@dominiodoemail.com.br           1
# 180       eder@dominiodoemail.com.br           2
# 181          yuri@servicodoemail.com           2
# 182    charles@dominiodoemail.com.br           1
# 183     marlon@dominiodoemail.com.br           1
# 184        alison@servicodoemail.com           2
# 185    jonatan@dominiodoemail.com.br           2
# 186          eric@servicodoemail.com           1
# 187         elton@servicodoemail.com           2
# 188   valdecir@dominiodoemail.com.br           1
# 189        weslei@servicodoemail.com           2
# 190      natanael@servicodoemail.com           2
# 191         erick@servicodoemail.com           1
# 192       agnaldo@servicodoemail.com           1
# 193         kauan@servicodoemail.com           1
# 194         odair@servicodoemail.com           2
# 195        walter@servicodoemail.com           1
# 196    arlindo@dominiodoemail.com.br           1
# 197    michael@dominiodoemail.com.br           1
# 198        alvaro@servicodoemail.com           3
# 199       geovane@servicodoemail.com           1
#
# [400 rows x 5 columns]

# %%
nomes.matriculas.describe()
# Out:
# count    400.000000
# mean       2.020000
# std        1.478196
# min        1.000000
# 25%        1.000000
# 50%        1.000000
# 75%        3.000000
# max       10.000000
# Name: matriculas, dtype: float64

# %%
import seaborn as sns

# %%
sns.distplot(nomes.matriculas)

# %%
nomes.matriculas.value_counts()
# Out:
# 1     203
# 2      93
# 3      55
# 4      24
# 5       9
# 6       8
# 7       3
# 9       2
# 8       2
# 10      1
# Name: matriculas, dtype: int64

# %%
nomes.sample(5)
# Out:
#           nome  id_alunos                 dominio  \
# 136     KARINA        317  @dominiodoemail.com.br
# 194      CLARA        238     @servicodoemail.com
# 178   DENILSON        297     @servicodoemail.com
# 52       LUZIA        377  @dominiodoemail.com.br
# 43   TEREZINHA        204     @servicodoemail.com
#
#                            e-mail  matriculas
# 136  karina@dominiodoemail.com.br           1
# 194      clara@servicodoemail.com           3
# 178   denilson@servicodoemail.com           2
# 52    luzia@dominiodoemail.com.br           1
# 43   terezinha@servicodoemail.com           1

# %% [markdown]
# ## Selecionando cursos:

# %%
todas_matriculas = []
x =np.random.rand(20)
prob = x/sum(x)

# %%
for index,row in nomes.iterrows():
    id = row.id_alunos
    matriculas = row.matriculas
    for i in range(matriculas):
        mat = [id,np.random.choice(cursos.index, p = prob)]
        todas_matriculas.append(mat)
        
matriculas = pd.DataFrame(todas_matriculas,columns = ['id_aluno','id_curso'])

matriculas.head(10)
# Out:
#    id_aluno  id_curso
# 0       126         2
# 1        66        18
# 2        66        12
# 3        66         4
# 4        66        12
# 5        66        11
# 6       295         9
# 7       272         8
# 8       272         5
# 9       272        14

# %%
matriculas_por_curso = matriculas.groupby('id_curso').count().join(cursos['nome_do_curso']).rename(columns= {'id_aluno':'quantidade_de_alunos'})

# %%
matriculas_por_curso
# Out:
#           quantidade_de_alunos                        nome_do_curso
# id_curso
# 1                           92                Lógica de programação
# 2                          132                        Java para Web
# 3                          118                          C# para Web
# 4                           68                        Ruby on Rails
# 5                           47                     Cursos de Python
# 6                           96                        PHP com MySql
# 7                           37                        .NET para web
# 8                          149           Novas integrações com Java
# 9                          116                         TDD com Java
# 10                          79                  Código limpo com C#
# 11                          94  Preparatório para certificação Java
# 12                         139                      Hardware básico
# 13                          27                Persistência com .NET
# 14                         114                  Desenvolvendo jogos
# 15                           2                     Análise de dados
# 16                          53                   Estatística básica
# 17                         112                  Internet das coisas
# 18                          75                Programação funcional
# 19                          41                Boas práticas em Java
# 20                          25          Orientação objetos com Java

# %% [markdown]
# ## Saida de diferentes formatos:

# %%
matriculas_por_curso.head(3)
# Out:
#           quantidade_de_alunos          nome_do_curso
# id_curso
# 1                           92  Lógica de programação
# 2                          132          Java para Web
# 3                          118            C# para Web

# %% [markdown]
# ## Criando o banco sql:

# %%
# !pip install sqlalchemy
# Out:
# Requirement already satisfied: sqlalchemy in c:\users\guilherme\anaconda3\lib\site-packages (1.3.1)

# %%
from sqlalchemy import create_engine, MetaData,Table

# %%
engine = create_engine('sqlite:///:memory:')

# %%
matriculas_por_curso.to_sql('matriculas',engine)

# %%
 print(engine.table_names())
# Out:
# ['matriculas']

# %% [markdown]
# ## Buscando do Banco SQL:

# %%
query = 'select * from matriculas where quantidade_de_alunos < 100'

# %%
pd.read_sql(query, engine)
# Out:
#     id_curso  quantidade_de_alunos                        nome_do_curso
# 0          1                    92                Lógica de programação
# 1          4                    68                        Ruby on Rails
# 2          5                    47                     Cursos de Python
# 3          6                    96                        PHP com MySql
# 4          7                    37                        .NET para web
# 5         10                    79                  Código limpo com C#
# 6         11                    94  Preparatório para certificação Java
# 7         13                    27                Persistência com .NET
# 8         15                     2                     Análise de dados
# 9         16                    53                   Estatística básica
# 10        18                    75                Programação funcional
# 11        19                    41                Boas práticas em Java
# 12        20                    25          Orientação objetos com Java

# %%
muitas_matriculas = pd.read_sql('matriculas', engine, columns = ['nome_do_curso','quantidade_de_alunos'])

# %%
muitas_matriculas = muitas_matriculas.query('quantidade_de_alunos>80')

# %% [markdown]
# ## Escrevendo no banco:

# %%
muitas_matriculas.to_sql('muitas_matriculas2',engine)

# %%
print(engine.table_names())
# Out:
# ['matriculas', 'muitas_matriculas', 'muitas_matriculas2']

# %%
proxima_turma = matriculas.query('id_curso == 16')
nomes.head(10)
# Out:
#         nome  id_alunos                 dominio  \
# 0      MARIA        126  @dominiodoemail.com.br
# 1        ANA         66     @servicodoemail.com
# 2  FRANCISCA        295  @dominiodoemail.com.br
# 3    ANTONIA        272  @dominiodoemail.com.br
# 4    ADRIANA        235     @servicodoemail.com
# 5    JULIANA        193     @servicodoemail.com
# 6     MARCIA        271     @servicodoemail.com
# 7   FERNANDA        375     @servicodoemail.com
# 8   PATRICIA        228     @servicodoemail.com
# 9      ALINE         62     @servicodoemail.com
#
#                             e-mail  matriculas
# 0      maria@dominiodoemail.com.br           1
# 1           ana@servicodoemail.com           5
# 2  francisca@dominiodoemail.com.br           1
# 3    antonia@dominiodoemail.com.br           3
# 4       adriana@servicodoemail.com           1
# 5       juliana@servicodoemail.com           2
# 6        marcia@servicodoemail.com           3
# 7      fernanda@servicodoemail.com           4
# 8      patricia@servicodoemail.com           1
# 9         aline@servicodoemail.com           2

# %%
proxima_turma.set_index('id_aluno').join(nomes.set_index('id_alunos'))
# Out:
#      id_curso        nome                 dominio  \
# 2          16     VIVIANE  @dominiodoemail.com.br
# 4          16        IARA     @servicodoemail.com
# 6          16     EDILSON  @dominiodoemail.com.br
# 8          16       OSMAR  @dominiodoemail.com.br
# 16         16       MARTA  @dominiodoemail.com.br
# 17         16       TIAGO  @dominiodoemail.com.br
# 18         16      LORENA     @servicodoemail.com
# 23         16     MARIANA  @dominiodoemail.com.br
# 24         16        DAVI     @servicodoemail.com
# 25         16     RAFAELA  @dominiodoemail.com.br
# 27         16  ALESSANDRA     @servicodoemail.com
# 28         16     LEANDRO  @dominiodoemail.com.br
# 32         16       VANIA  @dominiodoemail.com.br
# 39         16     CECILIA  @dominiodoemail.com.br
# 42         16     ADRIANO     @servicodoemail.com
# 50         16       SUELI  @dominiodoemail.com.br
# 53         16      NELSON  @dominiodoemail.com.br
# 53         16      NELSON  @dominiodoemail.com.br
# 53         16      NELSON  @dominiodoemail.com.br
# 59         16      RAQUEL  @dominiodoemail.com.br
# 59         16      RAQUEL  @dominiodoemail.com.br
# 74         16      SAMUEL  @dominiodoemail.com.br
# 84         16       ALICE     @servicodoemail.com
# 86         16     MARLENE  @dominiodoemail.com.br
# 99         16      SILVIO     @servicodoemail.com
# 99         16      SILVIO     @servicodoemail.com
# 107        16      OTAVIO  @dominiodoemail.com.br
# 114        16   CONCEICAO     @servicodoemail.com
# 123        16     ROBERTA  @dominiodoemail.com.br
# 148        16     MICHAEL  @dominiodoemail.com.br
# 162        16      EUNICE     @servicodoemail.com
# 172        16   ELIZABETE     @servicodoemail.com
# 176        16      WESLEI     @servicodoemail.com
# 181        16     VANESSA  @dominiodoemail.com.br
# 186        16      MONICA  @dominiodoemail.com.br
# 188        16       DAVID     @servicodoemail.com
# 193        16     JULIANA     @servicodoemail.com
# 213        16      FLAVIA  @dominiodoemail.com.br
# 250        16      MILENA     @servicodoemail.com
# 260        16     TAMIRES  @dominiodoemail.com.br
# 269        16       JAIME  @dominiodoemail.com.br
# 276        16     LARISSA     @servicodoemail.com
# 289        16      ROSANE  @dominiodoemail.com.br
# 302        16     ADILSON     @servicodoemail.com
# 309        16       PAULA     @servicodoemail.com
# 321        16      GILMAR     @servicodoemail.com
# 337        16        LARA     @servicodoemail.com
# 343        16   ALEXANDRA     @servicodoemail.com
# 347        16      JANETE     @servicodoemail.com
# 363        16      CINTIA  @dominiodoemail.com.br
# 369        16       ODAIR     @servicodoemail.com
# 386        16     ANDREIA     @servicodoemail.com
# 391        16     POLIANA  @dominiodoemail.com.br
#
#                             e-mail  matriculas
# 2    viviane@dominiodoemail.com.br           1
# 4          iara@servicodoemail.com           1
# 6    edilson@dominiodoemail.com.br           4
# 8      osmar@dominiodoemail.com.br           1
# 16     marta@dominiodoemail.com.br           3
# 17     tiago@dominiodoemail.com.br           3
# 18       lorena@servicodoemail.com           2
# 23   mariana@dominiodoemail.com.br           8
# 24         davi@servicodoemail.com           4
# 25   rafaela@dominiodoemail.com.br           1
# 27   alessandra@servicodoemail.com           7
# 28   leandro@dominiodoemail.com.br           1
# 32     vania@dominiodoemail.com.br           3
# 39   cecilia@dominiodoemail.com.br           2
# 42      adriano@servicodoemail.com          10
# 50     sueli@dominiodoemail.com.br           2
# 53    nelson@dominiodoemail.com.br           3
# 53    nelson@dominiodoemail.com.br           3
# 53    nelson@dominiodoemail.com.br           3
# 59    raquel@dominiodoemail.com.br           3
# 59    raquel@dominiodoemail.com.br           3
# 74    samuel@dominiodoemail.com.br           1
# 84        alice@servicodoemail.com           4
# 86   marlene@dominiodoemail.com.br           1
# 99       silvio@servicodoemail.com           3
# 99       silvio@servicodoemail.com           3
# 107   otavio@dominiodoemail.com.br           1
# 114   conceicao@servicodoemail.com           2
# 123  roberta@dominiodoemail.com.br           2
# 148  michael@dominiodoemail.com.br           1
# 162      eunice@servicodoemail.com           2
# 172   elizabete@servicodoemail.com           1
# 176      weslei@servicodoemail.com           2
# 181  vanessa@dominiodoemail.com.br           3
# 186   monica@dominiodoemail.com.br           1
# 188       david@servicodoemail.com           3
# 193     juliana@servicodoemail.com           2
# 213   flavia@dominiodoemail.com.br           4
# 250      milena@servicodoemail.com           2
# 260  tamires@dominiodoemail.com.br           2
# 269    jaime@dominiodoemail.com.br           4
# 276     larissa@servicodoemail.com           6
# 289   rosane@dominiodoemail.com.br           2
# 302     adilson@servicodoemail.com           7
# 309       paula@servicodoemail.com           4
# 321      gilmar@servicodoemail.com           4
# 337        lara@servicodoemail.com           4
# 343   alexandra@servicodoemail.com           3
# 347      janete@servicodoemail.com           2
# 363   cintia@dominiodoemail.com.br           1
# 369       odair@servicodoemail.com           2
# 386     andreia@servicodoemail.com           3
# 391  poliana@dominiodoemail.com.br           4

# %%
proxima_turma.set_index('id_aluno').join(nomes.set_index('id_alunos'))['nome']
# Out:
# 2         VIVIANE
# 4            IARA
# 6         EDILSON
# 8           OSMAR
# 16          MARTA
# 17          TIAGO
# 18         LORENA
# 23        MARIANA
# 24           DAVI
# 25        RAFAELA
# 27     ALESSANDRA
# 28        LEANDRO
# 32          VANIA
# 39        CECILIA
# 42        ADRIANO
# 50          SUELI
# 53         NELSON
# 53         NELSON
# 53         NELSON
# 59         RAQUEL
# 59         RAQUEL
# 74         SAMUEL
# 84          ALICE
# 86        MARLENE
# 99         SILVIO
# 99         SILVIO
# 107        OTAVIO
# 114     CONCEICAO
# 123       ROBERTA
# 148       MICHAEL
# 162        EUNICE
# 172     ELIZABETE
# 176        WESLEI
# 181       VANESSA
# 186        MONICA
# 188         DAVID
# 193       JULIANA
# 213        FLAVIA
# 250        MILENA
# 260       TAMIRES
# 269         JAIME
# 276       LARISSA
# 289        ROSANE
# 302       ADILSON
# 309         PAULA
# 321        GILMAR
# 337          LARA
# 343     ALEXANDRA
# 347        JANETE
# 363        CINTIA
# 369         ODAIR
# 386       ANDREIA
# 391       POLIANA
# Name: nome, dtype: object

# %%
proxima_turma = proxima_turma.set_index('id_aluno').join(nomes.set_index('id_alunos'))['nome'].to_frame()

# %%
nome_curso = cursos.loc[id_curso]
nome_curso
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-187-285c537bf07c> in <module>
# ----> 1 nome_curso = cursos.loc[id_curso]
#       2 nome_curso
#
# NameError: name 'id_curso' is not defined

# %%
nome_curso = 'Estatística básica'

# %%
proxima_turma.rename(columns= {'nome':f'Alunos do curso de {nome_curso}'})
# Out:
#     Alunos do curso de Estatística básica
# 2                                 VIVIANE
# 4                                    IARA
# 6                                 EDILSON
# 8                                   OSMAR
# 16                                  MARTA
# 17                                  TIAGO
# 18                                 LORENA
# 23                                MARIANA
# 24                                   DAVI
# 25                                RAFAELA
# 27                             ALESSANDRA
# 28                                LEANDRO
# 32                                  VANIA
# 39                                CECILIA
# 42                                ADRIANO
# 50                                  SUELI
# 53                                 NELSON
# 53                                 NELSON
# 53                                 NELSON
# 59                                 RAQUEL
# 59                                 RAQUEL
# 74                                 SAMUEL
# 84                                  ALICE
# 86                                MARLENE
# 99                                 SILVIO
# 99                                 SILVIO
# 107                                OTAVIO
# 114                             CONCEICAO
# 123                               ROBERTA
# 148                               MICHAEL
# 162                                EUNICE
# 172                             ELIZABETE
# 176                                WESLEI
# 181                               VANESSA
# 186                                MONICA
# 188                                 DAVID
# 193                               JULIANA
# 213                                FLAVIA
# 250                                MILENA
# 260                               TAMIRES
# 269                                 JAIME
# 276                               LARISSA
# 289                                ROSANE
# 302                               ADILSON
# 309                                 PAULA
# 321                                GILMAR
# 337                                  LARA
# 343                             ALEXANDRA
# 347                                JANETE
# 363                                CINTIA
# 369                                 ODAIR
# 386                               ANDREIA
# 391                               POLIANA
